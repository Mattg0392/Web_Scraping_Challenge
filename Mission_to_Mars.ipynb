# %%
pip install webdriver-manager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install splinter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup as BS
from splinter import Browser
import pandas as pd
import requests
import pymongo
import time

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
DB = client.Mission_DB
collection = DB.marsData

# %%
article_url = 'https://redplanetscience.com/data/item.json'
response = requests.get(article_url).json()
print(response)
# Create BS parser
#marsSoup = BS(response.text, "html.parser"
# Out:
# {'items': [{'id': 8822, 'title': "A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes", 'target': '_self', 'main_image_alt': "A tray holding 39 sample tubes – each protected in a gold-colored sheath – is installed in NASA's Perseverance rover in this picture taken at the agency's Kennedy Space Center on May 21, 2020.", 'meta_author': '', 'byline': '', 'meta_keywords': '', 'item_name': '', 'updated_at': '2020-12-22T17:24:30.741Z', 'url': '/news/8822/a-martian-roundtrip-nasas-perseverance-rover-sample-tubes/', 'missions': [[175, 'mep', 'Mars Exploration Program'], [180, 'mars2020', 'Mars 2020 Rover']], 'news_type': [[165, 'feature', 'Feature Stories']], 'description': "Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition. ", 'date': 'December 22, 2020', 'body': '<figure class=\'column-width embedded_video video_player_container\'>\n<div class=\'video_wrapper\'>\n<iframe
# ...

# %%
article = response['items'][0]
title = article['title']
description = article['description']

# %%
print(title)
print(description)
# Out:
# A Martian Roundtrip: NASA's Perseverance Rover Sample Tubes
# Marvels of engineering, the rover's sample tubes must be tough enough to safely bring Red Planet samples on the long journey back to Earth in immaculate condition.

# %%
from webdriver_manager.chrome import ChromeDriverManager
executable_path = {'executable_path': ChromeDriverManager().install()}
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# There is no [win32] chromedriver for browser 92.0.4515 in cache
# Get LATEST driver version for 92.0.4515
# Trying to download new driver from https://chromedriver.storage.googleapis.com/92.0.4515.107/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\Matthew\.wdm\drivers\chromedriver\win32\92.0.4515.107]

# %%
with Browser('chrome', **executable_path, headless=False) as browser:
    browser.visit('https://spaceimages-mars.com/')
    img_url = browser.find_by_css('img.headerimage').first['src']
    print(img_url)
# Out:
# https://spaceimages-mars.com/image/featured/mars2.jpg
